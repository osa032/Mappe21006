# %% [markdown]
# # Mappeoppgave 2 SOK-1006 Mikroøkonomi
#
# Kand.nr. 42

# %% [markdown]
# # Oppgave 1 - Kartlegging av detaljhandel i Norge

# %% [markdown]
# I denne oppgaven skal jeg definere og så kartlegge utviklingen av detaljhandelen i Norge. Jeg skal se på både oversiktelig omsetning og sysselsetting for hele næringen, for så å peile meg inn på et par produkter i tillegg til netthandel og se hvordan disse har utviklet seg over tid.
#
# Jeg forventer å se en dreining mot netthandel, men er interessert i å se på hvordan koronatiltakene påvirket næringen, og forventer å se en større endring i handelsmønster både under og etter koronakrisen. Dette både som en konsekvens av regjeringens tiltak for å forhindre spredning (som krav om nedstegning av fysiske butikker), men også på grunn av de, for mange, økonomisk usikre tidene som har kommet i etterkant.

# %% [markdown]
# ## i) Gi en definisjon av detaljhandelen i Norge.

# %% [markdown]
# Detaljhandel er en næringsinndeling som inneholder alt av virksomheter som driver salg av varer (nye og/eller brukte) til private husholdninger i eget navn og for egen regning. Eksempler på detaljhandel kan være: salg av mat, drikke, klær, sko, elektriske husholdningsapparater, møbler, byggevarer med mer. Det kan foregå enten fra fast utsalgssted, mobilt utsalgssted, torgplass eller per internett/postordre.
#
# I Norge har detaljnæringen gjennomgått betydelige endringer de siste årene, sterkt påvirket av pandemien. Mens noen endringer har skapt nye muligheter og økt verdiskaping, har andre skapt utfordringer med kostnadspress og behov for rask tilpasning.

# %% [markdown]
# ##  ii) Finn data hos Statistisk sentralbyrå som beskriver utviklingen av detaljhandelen i Norge.

# %% [markdown]
# #### Omsetningen i detaljhandelen

# %%
df_sorted = omsetning_47_df.sort_values('år', ascending=True)
plot_series(df_sorted, 'Omsetning i detaljhandelen i Norge 2008-2023',
            title="Fig.1: Omsetning i detaljhandelen i Norge 2008-2023",
            subtitle="Realomsetning (mill.kr)(2015=100)",
            undertext="Kilde: Statistisk sentralbyrå")

# %% [markdown]
# Fig.1 Utviklingen i realomsetningen i hele detaljhandelen i Norge fra 2008 til 2023.
#
# Vi ser:
#
# Stabil Vekst Før 2019: Grafen viser en gradvis økning i realomsetningen frem til 2019, noe som indikerer en stabil økonomisk vekst og økt kjøpekraft i denne perioden.
#
# Signifikant Økning Under Pandemien: Det er en markant økning i realomsetningen fra 2019 til 2021. Dette skyldes blant annet stengte grenser som førte til redusert grensehandel, samt at folk brukte mer penger på varer da andre forbruksmuligheter, som reiser og opplevelser, var begrenset.
#
# Nedgang Etter Pandemien: Etter toppåret 2021 ser vi en nedgang i omsetningen, noe som kan tyde på en normalisering av forbruksmønstre og gjenopptakelse av grensehandel og andre forbruksmuligheter.

# %% [markdown]
# ### Sysselsetting i detaljhandelen

# %%
df_retail = pd.DataFrame(df_12910)
df_norway = pd.DataFrame(df_12910_hele)

# Define the years for which you want to create pie charts
selected_years = [df_retail['år'].min(), df_retail['år'].max()]

create_pie_charts(df_retail, df_norway, selected_years)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="81448fca-1968-44fc-b63f-fbab890901ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81448fca-1968-44fc-b63f-fbab890901ff")) {                    Plotly.newPlot(                        "81448fca-1968-44fc-b63f-fbab890901ff",                        [{"domain":{"x":[0.0,0.45],"y":[0.0,1.0]},"hole":0,"hoverinfo":"percent+value","hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Detaljhandel","Andre N\u00e6ringer"],"legendgroup":"","marker":{"colors":["#ff9999","#66b3ff"]},"name":"","showlegend":true,"textinfo":"percent","values":[232270.0,1376045.0],"type":"pie"},{"domain":{"x":[0.55,1.0],"y":[0.0,1.0]},"hole":0,"hoverinfo":"percent+value","hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Detaljhandel","Andre N\u00e6ringer"],"legendgroup":"","marker":{"colors":["#ff9999","#66b3ff"]},"name":"","showlegend":true,"textinfo":"percent","values":[218741.0,1688682.0],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0," ...

# %% [markdown]
# Fig.2 Sysselsettingen i detaljhnadelen og resten av Norge 2017 og 2022
#
# Vi ser:
#
# 1. Andel Ansatte i Detaljhandelen:
#  - 2017: Indikerer at 14,4% av de ansatte var i detaljhandelssektoren, mens 85,6% var ansatt i andre sektorer.
#  - 2022: I 2022 hadde andelen ansatte i detaljhandelssektoren sunket til 11,5%
#
# Potensielle grunner:
# - Automatisering og Digitalisering: En mulig årsak til nedgangen i andelen ansatte i detaljhandelen er økt automatisering og digitalisering i sektoren. Netthandel og selvbetjeningskasser reduserer behovet for menneskelig arbeidskraft i tradisjonelle butikker.
# - Skift til E-handel: Når flere forbrukere går over til netthandel, reduseres etterspørselen etter tradisjonelle butikkansatte. Dette skiftet omdisponerer jobber fra tradisjonell detaljhandel til logistikk, lager og leveringstjenester knyttet til e-handel.
# - Økonomiske Endringer: Endringer i forbrukeradferd, økonomiske politikker og markedsforhold kan også påvirke sysselsettingstrendene. Økonomiske nedgangstider eller endringer i forbruksmønstre kan påvirke sysselsettingen i detaljhandelen negativt.

# %% [markdown]
# ## iiiA) Velg ut noen produkter og vis hvordan omsetning av disse har utviklet seg over tid.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Split the data for the two industries
spill = Omsetning_07313[Omsetning_07313["næring (SN2007)"] == "Butikkhandel med spill og leker"]
klar = Omsetning_07313[Omsetning_07313["næring (SN2007)"] == "Butikkhandel med klær"]
kosm = Omsetning_07313[Omsetning_07313["næring (SN2007)"] == "Butikkhandel med kosmetikk og toalettartikler"]
brukt = Omsetning_07313[Omsetning_07313["næring (SN2007)"] == "Butikkhandel med brukte varer"]

# Plotting
plt.figure(figsize=(12, 8))
plt.plot(spill["år"], spill["Realomsetning (mill.kr)(2015=100)"], marker='o', label='Butikkhandel med spill og leker')
plt.plot(klar["år"], klar["Realomsetning (mill.kr)(2015=100)"], marker='o', label='Butikkhandel med klær')
plt.plot(kosm["år"], kosm["Realomsetning (mill.kr)(2015=100)"], marker='o', label='Butikkhandel med kosmetikk og toalettartikler')
plt.plot(brukt["år"], brukt["Realomsetning (mill.kr)(2015=100)"], marker='o', label='Butikkhandel med brukte varer')

# Set labels and title
plt.xlabel('År')
plt.ylabel('Realomsetning (mill. kr) (2015=100)')
plt.title('Fig.3 Realomsetning for Butikkhandel med ulike varegrupper (2008-2023)\nKilde: Statistisk Sentralbyrå Tabell 07313')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# Figur 4 Viser realomsetning for ulike næringer under detaljhandel fra 2008 til 2023, basert på data fra Statistisk Sentralbyrå Tabell 07313. Grafen viser realomsetning (målt i millioner kroner, 2015=100) for fire forskjellige varegrupper:
# - Butikkhandel med spill og leker (blå linje)
#     - Realomsetningen har vært ganske stabil med noen små svingninger, men ingen klare oppad- eller nedadgående trender. Dette blandt annet tilskrives digitalisering: Overgangen til digitale spill kan ha påvirket salg av fysiske spill og leker, men samtidig har tradisjonelle leker fortsatt en stabil etterspørsel.
#
# - Butikkhandel med klær (oransje linje)
#     - Denne varegruppen viser en relativt stabil omsetning fra 2008 til 2019, med en gradvis nedgang etter 2019. Dette kan tilskrives flere faktorer:
#         - Økt netthandel: Økende preferanse for å kjøpe klær på nett har redusert omsetningen i fysiske butikker.
#         - Covid-19-pandemien: Restriksjoner og endringer i forbrukeratferd under pandemien har påvirket klesbutikker negativt.
#         - Økt konkurranse: Flere aktører på markedet og internasjonale butikker har økt konkurransen.
#
# - Butikkhandel med kosmetikk og toalettartikler (grønn linje)
#     - Denne varegruppen viser en svak økning i realomsetning gjennom perioden. Noen grunner kan være:
#         - Økt fokus på personlig pleie: Økt bevissthet rundt skjønnhet og personlig pleie har drevet etterspørselen oppover. I krisetider kjøper kvinner lebestift [source?].
#         - Nye produkter og markeder: Innovasjon og lansering av nye produkter kan ha bidratt til økningen
# - Butikkhandel med brukte varer (rød linje)
#     - Denne varegruppen viser en relativt lav, men stabil omsetning:
#         - Bærekraftstrender: Økt bevissthet rundt bærekraft og gjenbruk har kanskje ikke helt slått gjennom i form av høy omsetning, men viser stabilitet.
#         - Markedsnicher: Butikker med brukte varer betjener spesifikke nisjemarkeder som kan forklare den lave, men stabile omsetningen.

# %% [markdown]
# ## iiiB) Vis hvordan netthandelen har utviklet seg over tid, samt hvilken andelen av den totale omsetningen for detaljhandel denne kategorien utgjør.

# %%
df_sorted = Omsetning_07313_nett.sort_values('år', ascending=True)
plot_series(df_sorted, 'Omsetning i netthandelen i Norge 2008-2023',
            title="Fig.4: Omsetning i netthandelen i Norge 2008-2023",
            subtitle="Realomsetning (mill.kr)(2015=100)",
            undertext="Kilde: Statistisk sentralbyrå tabell 07313")

# %% [markdown]
# Figur 4 viser utviklingen i realomsetningen for netthandel i Norge fra 2008 til 2023.
#
# Kraftig Vekst Over Tid: Netthandel viser en jevn økning i omsetningen over hele perioden, med en spesielt kraftig vekst fra 2019 til 2021.
#
# Pandemiens Effekt: Den markante økningen i netthandel under pandemien kan tilskrives restriksjoner på fysisk handel, økt bruk av digitale løsninger og et skifte i forbruksmønstre mot mer online shopping.
#
# Nedgang Etter Pandemien: Etter toppåret 2021 ser vi en nedgang, men omsetningen er fortsatt betydelig høyere enn pre-pandemiske nivåer. Dette indikerer at netthandel har fått en mer permanent plass i forbrukernes handlemønstre, selv om noe av den eksepsjonelle veksten har normalisert seg.

# %% [markdown]
# ### Oppsummering av Detaljhandelen
#
# #### Før Covid-19
# Før pandemien var detaljhandelen preget av en stabil vekst, men også utfordringer som påvirket både forbrukere og bedrifter.
#
# 1. **Stabil Vekst:** Detaljhandelen i Norge opplevde en jevn vekst, drevet av økende kjøpekraft og lav arbeidsledighet. Forbruksmønstrene var preget av økt etterspørsel etter både tradisjonelle varer og netthandel.
#
# 2. **Økt Konkurranse:** Bedrifter møtte økt konkurranse fra netthandel og internasjonale aktører. Dette presset marginene og tvang mange til å innovere og tilpasse seg raskt skiftende forbrukerpreferanser.
#
# 3. **Grensehandel:** Grensehandel med Sverige var en betydelig faktor, spesielt for dagligvarer og alkohol. Dette førte til tap av omsetning for norske butikker nær grensen.
#
# #### Under Covid-19
# Pandemien hadde en dramatisk effekt på detaljhandelen, og skapte både utfordringer og muligheter.
#
# 1. **Stengte Grenser og Økt Omsetning:** Med stengte grenser økte omsetningen i norske dagligvarebutikker betydelig. Kjøpesentrene opplevde en vekst på over 20 % i omsetningen i juli 2020, noe som var den største veksten på mer enn 40 år【source1】.
#
# 2. **Endringer i Forbruksmønstre:** Forbrukere tilpasset seg nye måter å handle på, med økt fokus på netthandel og ukeshandling. Mange prøvde hjemleveringstjenester for første gang og fant dette praktisk og tidsbesparende【source2】.
#
# 3. **Pris- og Kostnadsutfordringer:** Økte råvarepriser, en svak krone, og høyere levekostnader påvirket bedriftene negativt. Mange bedrifter opplevde også press på marginene på grunn av høye lagerbeholdninger og dalende etterspørsel etter varer etter gjenåpningen【source3】.
#
# #### Etter Covid-19
# Etter pandemien har detaljhandelen begynt å normalisere seg, men det er fortsatt betydelige utfordringer og langsiktige endringer.
#
# 1. **Normalisering av Forbruk:** Etter den kraftige økningen under pandemien, har detaljhandelen sett en nedgang, men omsetningen ligger fortsatt høyere enn i normalåret 2019. Detaljhandelen falt med 0,3 % i september 2023, som var den tredje måneden på rad med nedgang【source4】.
#
# 2. **Makroøkonomiske Faktorer:** Norges Bank har økt renten for å dempe inflasjonen, som påvirker forbrukernes kjøpekraft og dermed detaljhandelen. Høye strøm-, drivstoff- og matpriser har dempet forbruket ytterligere【source3】【source2】.
#
# 3. **Langsiktige Trender:** Økningen i netthandel og hjemlevering under pandemien ser ut til å bli en varig endring. Forbrukere har blitt vant til bekvemmeligheten av netthandel, og dette krever at detaljhandelsbedrifter fortsetter å tilpasse seg digitale plattformer for å forbli konkurransedyktige.
#
# ### Samfunnsøkonomiske Effekter
# De samfunnsøkonomiske effektene av endringene i detaljhandelen kan oppsummeres slik:
#
# 1. **Økt Verdiskaping:** Økt omsetning i norsk detaljhandel under pandemien bidro til økt verdiskaping og sysselsetting. En vedvarende økning i omsetningen kan skape flere arbeidsplasser og økte skatteinntekter for staten【source4】.
#
# 2. **Kostnadspress:** Høyere kostnader for råvarer, transport og energi legger press på detaljhandelsbedriftenes marginer. Dette kan føre til økte priser for forbrukerne og redusert kjøpekraft【source】.
#
# 3. **Strukturelle Endringer:** Den økte digitaliseringen og endrede forbruksmønstre krever tilpasning fra bedriftene. De som ikke klarer å tilpasse seg nye teknologier og forbrukervaner risikerer å bli utkonkurrert【source1】【source2】.
#
# ### Konklusjon
#
# Detaljhandelen i Norge har gjennomgått betydelige endringer fra 2008 til 2023. Mens hele sektoren og netthandelen opplevde en betydelig vekst under pandemien, viser post-pandemiske trender en viss normalisering. Samtidig har flere bransjer hatt utfordringer med å nå tilbake til tidligere omsetningsnivåer, noe som kan være et resultat av endrede forbruksmønstre og vedvarende konkurranse fra netthandel. Disse trendene reflekterer en samfunnsøkonomisk omstilling i detaljhandelen, hvor digitalisering og endrede kjøpsvaner spiller en sentral rolle.

# %% [markdown]
# # Oppgave 2 - Produktfunksjon for detaljhandel
#
# I denne oppgaven skal du estimere en produktfunksjon for detaljhandel i Norge. Vi antar at produktfunksjonen tar Cobb-Douglas form:
#
# $$ x = ZN^a K^b \ (1)$$
#
# hvor $x$ er enheter ferdigprodukt, $N$ er enheter arbeidskraft, $K$ er enheter kapital og $Z>0$, $a>0$, $b>0$ er konstante tall.
#
# [Tabell 12910, SSB](https://www.ssb.no/statbank/table/12910/) inneholder data etter næring på blant annet Produksjonsverdi, Lønnskostnader og Bruttoinvesteringer (alle i mill NOK), bruk disse til å henholdsvis beregne K, N og x for detlajhandelen i Norge.

# %% [markdown]
# ## i) Estimer Z, a, b og forklar nøye hva hvert tall representerer.

# %% [markdown]
# En Cobb-Douglas-produksjonsfunksjon er en spesifikk type produksjonsfunksjon som brukes i økonomi for å beskrive forholdet mellom innsatsfaktorer (input) og produksjon (output).
#
# Den kan brukes til å modellere produksjonsprosesser i ulike industrier. Ved å bruke data om output ($y$), arbeidskraft ($N$) og kapital ($K$), (her estimert av tabell 12910 som Produksjonsverdi, Lønnskostnader og Bruttoinvesteringer) kan vi estimere verdiene for innsattsfaktorene $Z$, $a$ og $b$ for å forstå hvordan endringer i disse vil påvirke produksjonen.
#
# ***Fordeler, begrensninger/antakelser ved Cobb-Douglas produktfunksjon***
#
# **Fordeler:**
# - Gir innsikt i hvordan ulike innsatsfaktorer påvirker produksjonen.
#
# **Begrensninger/antakelser:**
# - Antar konstant skalautbytte over tid og teknologi. Det vil si at om det er flere faktorer enn Kapital og Arbeidskraft så vil disse ha en konstant utbytte uavhengig av de andre faktorene.
# - Forutsetter perfekte markeder og fravær av eksternaliteter. Altså at det ikke er andre faktorer som påvirker produksjonen enn de vi legger inn i funksjonen.

# %% [markdown]
# Av oppgaven får vi at Cobb-Douglas-funksjonen har formen:
#
# $$ Y = Z \cdot N^a \cdot K^b $$
#
# Hvor:
# - $ Y $ er produksjonsnivået (output).
# - $ Z $ er en konstant som representerer total faktorproduktivitet (TFP), også kjent som teknologi eller effektivitet. Dette er en skalar som påvirker hvor effektivt inputs (N og K) blir omdannet til output.
# - $ N $ er mengden arbeidskraft som brukes i produksjonen.
# - $ K $ er mengden kapital som brukes i produksjonen.
# - $ a $ er outputelastisiteten til arbeidskraft, som indikerer prosentvis endring i output når arbeidskraften øker med 1%, gitt at alle andre faktorer er konstante.
# - $ b $ er outputelastisiteten til kapital, som indikerer prosentvis endring i output når kapitalen øker med 1%, gitt at alle andre faktorer er konstante.

# %% [markdown]
# For å estimere parameterne $Z$, $a$ og $b$ tar jeg disse stegene:
#
# 1. **Logaritmisk transformasjon**:
#    Transformerer Cobb-Douglas-funksjonen til en lineær form ved bruk av logaritmer for å kunne bruke lineær regresjon til å estimere parametrene.
#
#    Siden den ordinære produksjonsfunksjonen ser slik ut:
#
#    $$Y = Z \cdot N^a \cdot K^b$$
#
#   Blir den logaritmiske formen av Cobb-Douglas-funksjonen slik:
#
#    $$log(Y) = \log(Z) + a \cdot \log(N) + b \cdot \log(K)$$
#
#    Hvor $log(Y)$ er $y$, $log(N)$ er $n$, og $log(K)$ er $k$. Da blir ligningen:
#
#
#    $$y = \log(Z) + a \cdot n + b \cdot k$$
#
#
# 2. **Data**:
#    Av dataene fra tabell 12910 får vi av oppgaven at:
#
# - $Y$ er totalproduksjonen (Produksjonsverdi),
# - $N$ er lønnskostnadene (Lønnskostnader),
# - $K$ er bruttoinvesteringene (Bruttoinvesteringer),
#
#
# 3. **Lineær regresjon**:
#    Etter å ha konvertert likningen til en lineær likning, og funnet frem tallene jeg skal bruke kjører jeg en multippel lineær regresjonsanalyse for å estimere koeffisientene. Koeffisienten for konstantleddet vil gi $log(Z)$, og koeffisientene for $n$ og $k$ vil gi henholdsvis $a$ og $b$.

# %%
print(model_summary)
print(f"Z: {Z}")
print(f"a: {a}")
print(f"b: {b}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  log_x   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     522.2
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):           8.16e-38
# Time:                        16:14:38   Log-Likelihood:                -27.062
# No. Observations:                  61   AIC:                             60.12
# Df Residuals:                      58   BIC:                             66.46
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5837      0.290      5.465      0.000       1.004       2.164
# log_K          0.1513      0.060      2.536      0.014       0.032       0.271
# log_N          0.8088      0.073     11.109      0.000       0.663       0.954
# ==============================================================================
# Omnibus:                       11.272   Durbin-Watson:                   1.439
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               18.845
# Skew:                           0.561   Prob(JB):                     8.09e-05
# Kurtosis:                       5.481   Cond. No.                         48.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Z: 4.872952420935827
# a: 0.8088
# b: 0.1513

# %% [markdown]
# Her får vi at Z er dette a er dette og b er dette. Fra regresjonstabellen ser vi at P-verdien til log_K (b) er over ideelt, men de andre er veldig gode.

# %% [markdown]
# ## Hva menes med skalautbytte, og hvordan kan man avgjøre skalautbytte for en produktfunksjon av type Cobb-Douglas?

# %% [markdown]
# Skalautbytte refererer til hvordan endringen i mengden av alle innsatsfaktorer påvirker mengden av output. For en Cobb-Douglas-produksjonsfunksjon avgjør man typen skalautbytte ved å summere eksponentene $a$ og $b$:
#
# - Hvis $a + b = 1$, er det konstant skalautbytte. Dette betyr at en proporsjonal økning i alle innsatsfaktorer fører til en like stor prosentvis økning i output.
# - Hvis $a + b > 1$, er det økende skalautbytte. Dette betyr at en proporsjonal økning i alle innsatsfaktorer fører til en større prosentvis økning i output.
# - Hvis $a + b < 1$, er det avtakende skalautbytte. Dette betyr at en proporsjonal økning i alle innsatsfaktorer fører til en mindre prosentvis økning i output.

# %% [markdown]
# ##  Hvilken skalaegenskap har produktfunksjonen for detaljhandel som du har estimert? Hvordan forklarer du dette (dvs er svaret intuitivt rimelig utfra type næring som vanligvis har denne type skalautbytte)?

# %% [markdown]
# For å finne skalaegenskapen til denne funksjonen, summerer jeg verdiene for $a$ og $b$:
# $$a + b = 0.81 + 0.15 = 0.96$$
#
# Siden $a + b < 1$, er det avtakende skalautbytte. Dette betyr at en proporsjonal økning i både arbeidskraft (N) og kapital (K) vil føre til en mindre enn proporsjonal økning i output.

# %% [markdown]
# Siden p-verdien for a var noe høy kan jeg sjekke dette ved å utføre denne ligningen: den gir meg en alternativ form for a og b som kan gjøre ting mulig.

# %% [markdown]
# - Intuisjonen ifht næring
#
# Detaljhandelnæringen er ofte preget av mange små aktører og høy konkurranse. Avtakende skalautbytte kan reflektere flere realiteter i denne sektoren (spesielt i år 2022):
#
# - **Effektivitetstap ved skalering**: Når detaljhandelsselskaper vokser, kan de oppleve ineffektivitet, som gjør det vanskelig å holde samme nivå av produktivitet.
# - **Markedsmetning**: Etter hvert som flere ressurser allokeres til detaljhandel, kan markedsmetning føre til mindre avkastning på investert kapital og arbeidskraft, ettersom det blir vanskeligere å finne nye kunder.
# - **Covid-19 effekter**: Pandemien har også forstyrret mange aspekter av detaljhandelen, noe som kan ha redusert effektiviteten i sektoren.
#
# Siden mange bedrifter kan ha slitt med å opprettholde effektiviteten med økte kostnader og endringer i forbrukeratferd kan det gi mening at data fra 2022 gir inntrykk av avtakende skalautbytte.

# %% [markdown]
# ## Hvilke svakheter har denne analysen?

# %% [markdown]
# Dataegenskaper: Dataene er fra 2022, en tid som kan være sterkt affektert av COVID-19 og nedgangskonjunkturen som kom etter.
#
# Måleproblemer: Dataene er en estimering basert på andre faktorer, det er også en ekstrem forenkling.
#
# Segmentspesifike dynamikker: Ulike segmenter av detaljhandelsmarkedet kan oppleve varierende skalautbytte så det er mulig at ved å slå alle under en kam blir det et for gengerelt overblikk.
#
# Valget av produktfunksjon kan også være lite ideell.
#
# En Cobb-Douglas funksjon forutsetter perfekte markeder og ingen eksternaliteter som ikke samsvarer med virkeligheten.

# %% [markdown]
# # Oppgave 3
#
# Butikken "Helt midt på treet" er en ganske *gjennomsnittlig* bedrift i en bransje i detaljhandelen. I denne sammenhengen betyr gjennomsnittlig følgende:
#
# - $Z, a, b$ som du fant i oppgave 2 beskriver produktfunksjonen til bedriften.
# - Én timeslønn i denne bedriften tilsvarer gjennomsnittet for detaljhandelen.
# - På kort sikt har bedriften kapitalutgifter som tilsvarer gjennomsnittet for detaljhandelen.
#
# I praksis betyr dette at du kan bruke dine estimat på $Z, a, b$ (ta 2 desimalplasser) som bedriftens produktfunksjon i (1), at timelønna er 287 kr i 2022, og at kapitalutgiften er gjennomsnittet av det som du har i datasettet (som du må finne). (Tabell 11421, SSB gir gjennomsnittlig månedslønn i 2022 for en ansatt i gruppe 47 Detaljhandel som 41 290 kr. SSB sier videre at en ansatt i full stilling arbeider 230 dager i året, som utgjør 19.2 dager i snitt pr måned, eller ($19.2*7.5=$) 144 timer pr måned).
#
# Vi går ut fra at "Helt midt på treet" har følgende produktfunksjon:
#
#
# \begin{equation}
#    y = ZL^aK_0^{b}\;\;(2)
# \end{equation}
#
# Her er $y$ antall enheter produsert, $L$ antall timer arbeidskraft, mens $K_0$ er kapitalutgiften til bedriften i mill. NOK. (Legg merke til at vi nå blander fysiske og monetære enheter).

# %% [markdown]
# ## i) Skriv et uttrykk for bedriftens variable og totale kostnader på kort sikt som en funksjon av mengde produsert (y)

# %% [markdown]
# Først må jeg finne $K_0$ ved å finne den gjennomsnittelige verdien for "Bruttoinvesteringer"

# %%
print(oppg_2_df['Bruttoinvesteringer (mill. kr)'].mean())
# Out:
# 271.2737704918033

# %% [markdown]
# Finn bedriftens variable kostnader og totale kostnader på kort sikt som en funksjon av mengde produsert $y$:
#
# 1. Finn uttrykk for arbeidskraft $L$ som en funksjon av produksjon $y$.
# Produksjonsfunksjonen er gitt som:
# $$y = Z \cdot L^a \cdot K_0^b$$
#
# Vi vet at:
# - $ Z = 4.87 $
# - $ a = 0.81 $
# - $ b = 0.15 $
# - $ w = 287  $
# - $ K_0 = 271$
#
# Dermed blir $L$ som en funksjon av $y$:
# $y = 4.87 \cdot L^{0.81} \cdot (271)^{0.15}$
#
# Konstantene blir da:
# $$(271)^{0.15} \approx 1.926 $$
# $$ y = 4.87 \cdot 1.926 \cdot L^{0.81} $$
# $$y \approx 9.374 \cdot L^{0.81}$$
#
# Løser for $L$:
# $$L^{0.81} = \frac{y}{9.374} $$
# $$L = \left( \frac{y}{9.374} \right)^{\frac{1}{0.81}}$$
#
#
# 2. Uttrykk for variable kostnader (VC)
# De variable kostnadene er lønnskostnadene, eller produktet av lønnen per time $w$ og mengden arbeidskraft $L$.
#
# Lønnen per time er:
# $w = 287 \, \text{NOK per time} $
#
# Da blir de variable kostnadene som en funksjon av produksjon $y$:
# $$VC(y) = w \cdot L $$
# $$VC(y) = 287 \cdot \left( \frac{y}{9.374} \right)^{\frac{1}{0.81}}$$
#
# 3. Totale kostnader (TC)
# De totale kostnadene på kort sikt inkluderer de faste kostnadene og de variable kostnadene. Vi antar at kapitalen er en fast kostnad som ikke endres med produksjonsnivået.
#
# De faste kostnadene (FC) er da bare kostnadene til kapital $K_0$:
#
# $$FC = K_0 \cdot 10^6 \, \text{NOK}$$
# $$FC = 271 \, \text{millioner NOK} = 271 \cdot 10^6 \, \text{NOK} = 2710000 \, \text{NOK} $$
#
# De totale kostnadene (TC) er da summen av de variable og faste kostnadene:
# $$TC(y) = VC(y) + FC $$
# $$TC(y) = 287 \cdot \left( \frac{y}{9.374} \right)^{\frac{1}{0.81}} + 2519000 $$
#
# 4. Oppsummering
# Uttrykk for bedriftens variable kostnader som en funksjon av mengde produsert $(y)$:
# $$VC(y) = 287 \cdot \left( \frac{y}{5.683} \right)^{\frac{1}{0.81}} $$
#
# Uttrykk for bedriftens totale kostnader som en funksjon av mengde produsert $(y)$:
# $$TC(y) = 287 \cdot \left( \frac{y}{5.683} \right)^{\frac{1}{0.81}} + 2519000 $$

# %% [markdown]
# ## ii)Finn uttrykk for bedriftens grensekostnad og gjennomsnittskostnad (total og variabel)

# %% [markdown]
# Vi vet fra forrige deloppgave at uttrykket for arbeidskraft $L$ som en funksjon av produksjon $y$ er:
#
# $$ L = \left( \frac{y}{9.374} \right)^{\frac{1}{0.81}} $$
#
# 1. Finn grensekostnad (MC)
#
# Grensekostnadene (MC) er den deriverte av de totale kostnadene (TC) med hensyn til produksjonsnivået $y$:
#
# $$MC(y) = \frac{dTC(y)}{dy} $$
#
# Beregner den deriverte:
# $$ VC(y) = 287 \cdot \left( \frac{y}{9.374} \right)^{\frac{1}{0.81}} $$
# $$VC(y) = 287 \cdot \left( \frac{y}{9.374} \right)^{1.2346} $$
#
#
# Deriverer så VC(y):
# $$ MC(y) = \frac{d}{dy} \left[ 287 \cdot \left( \frac{y}{9.374} \right)^{1.2346} \right]  $$
#
# $$ MC(y) = 287 \cdot 1.2346 \cdot \left( \frac{y}{9.374} \right)^{0.2346} \cdot \frac{1}{9.374}$$
#
# $$ MC(y) = 287 \cdot 1.2346 \cdot 9.374^{-1.2346} \cdot y^{0.2346} $$
#
# 2. Finn gjennomsnittskostnad (AC)
#
# Gjennomsnittskostnadene (AC) er de totale kostnadene (TC) delt på mengde produsert $y$:
#
# $$ AC(y) = \frac{TC(y)}{y} $$
#
# Beregner uttrykket for $( TC(y) )$:
# $$ TC(y) = 287 \cdot \left( \frac{y}{9.374} \right)^{1.2346} + 271,000,000 $$
#
# Da blir:
# $$ AC(y) = \frac{287 \cdot \left( \frac{y}{9.374} \right)^{1.2346} + 271,000,000}{y} $$
#
# Gjennomsnittlig variable kostnader (AVC):
# $$ AVC(y) = \frac{VC(y)}{y} $$
# $$AVC(y) = \frac{287 \cdot \left( \frac{y}{9.374} \right)^{1.2346}}{y} $$
#
# ### Oppsummering
#
# - **Grensekostnad (MC)**:
# $ MC(y) = 287 \cdot 1.2346 \cdot 9.374^{-1.2346} \cdot y^{0.2346}  $
#
# - **Gjennomsnittskostnad (AC)**:
# $ AC(y) = \frac{287 \cdot \left( \frac{y}{9.374} \right)^{1.2346} + 271,000,000}{y} $
#
# - **Gjennomsnittlig variable kostnader (AVC)**:
# $ AVC(y) = \frac{287 \cdot \left( \frac{y}{9.374} \right)^{1.2346}}{y}  $

# %% [markdown]
# ## iii) Bruk ditt svar til ii) for å tegne bedriftens tilbudskurve i en figur. Forklar figuren nøye.

# %%
# Graf for oppgave 3
import numpy as np
import matplotlib.pyplot as plt

# Definer konstanter med de gitte verdiene
a = 0.81
Z = 4.75
K0 = 271
w = 287
b = 0.15
k = w * (1 / (Z * K0**b))**(1/a)

# Definer grensekostnadsfunksjonen
def MC(y):
    return (k / a) * y**(1/a - 1)

# Definer gjennomsnittlig variabel kostnadsfunksjon (AVC) og gjennomsnittlig total kostnadsfunksjon (ATC)
def AVC(y):
    return k * y**(1/a - 1)

def ATC(y):
    return AVC(y) + K0 / y  # cK0 is a placeholder for fixed cost per unit, assume c = 1 for simplification

# Lag en rekke med produksjonsnivåer
y = np.linspace(0.1, 1000, 1000)  # unngå y=0 for å unngå deling på null

# Beregn MC, AVC og ATC verdier
mc_values = MC(y)
avc_values = AVC(y)
atc_values = ATC(y)

# Identifisere og highlight tilbudskurven (delen av MC over AVC)
supply_curve_y_before = y[mc_values > atc_values]
supply_curve_MC_before = mc_values[mc_values > atc_values]


# Plotting
plt.figure(figsize=(10, 6))
plt.plot(y, mc_values, label='Grensekostnad (GK)', color='blue')
plt.plot(y, atc_values, label='Gjennomsnittlig total kostnad (ATC)', color='green')
plt.plot(supply_curve_y_before, supply_curve_MC_before, label='Tilbudskurve',  color='red')

# Sett aksene
plt.xlabel('Kvantum (y)')
plt.ylabel('Pris / Kostnad')
plt.title('Kostnadskurver (GK, AVC, ATC)')
plt.legend()
plt.grid(True)
plt.ylim(0, 100)  # Begrens y-aksen for klarhet
plt.xlim(0, 1000)  # Begrens x-aksen for klarhet
plt.show()

# %% [markdown]
# Figuren viser tre kurver:
#
# GK(MC) som representerer bedriftens grensekostnader. Den forteller oss hvor mye det koster bedriften å produsere en ekstra enhet av hva nå enn de produserer. Ofte er det ikke lønnsomt å bare produsere én enhet siden det inngår faste og variable kostnader som synker per ekstra enhet produsert frem til det når et optimum hvor da prisen blir dyerer igjen per enhet produert.
#
# GTC - Gjennomsnittelig total kostnad. Forteller oss hvor mye det koster bedriften å produsere en ekstra enhet i tillegg til de totale kostnadene.
#
# Tilbudskurven - Det ormådet der det er lønnsomt for bedriften å produsere.
#
# Det er også greit å bemerke seg at denne bedriften ikke har merproduksjonskostnader (r) dette er fordi det er detaljhandel som videreselger varer, så de burde ikke ha ekstra kostnader til foredling.

# %% [markdown]
# ## Anta at lønnsoppgjøret gir arbeidere i "Helt midt på treet" en lønnsøkning på 5%. Vis hvordan dette påvirker bedriftens tilbud, og forklar intuisjonen bak endringen.

# %%
# Graf for oppgave 3.2
import numpy as np
import matplotlib.pyplot as plt

# Definer konstanter med de gitte verdiene
a = 0.81
Z = 4.75
K0 = 271
w = 287
w2 = w * 1.05
b = 0.15
k = w * (1 / (Z * K0**b))**(1/a)
k2 = w2 * (1 / (Z * K0**b))**(1/a)

# Definer grensekostnadsfunksjonen
def MC(y):
    return (k / a) * y**(1/a - 1)

# Definer gjennomsnittlig variabel kostnadsfunksjon (AVC) og gjennomsnittlig total kostnadsfunksjon (ATC)
def AVC(y):
    return k * y**(1/a - 1)

def ATC(y):
    return AVC(y) + K0 / y  # cK0 is a placeholder for fixed cost per unit, assume c = 1 for simplification

# Definer grensekostnadsfunksjonen
def MC2(y):
    return (k2 / a) * y**(1/a - 1)

# Lag en rekke med produksjonsnivåer
y = np.linspace(0.1, 1000, 1000)  # unngå y=0 for å unngå deling på null

# Beregn MC, AVC og ATC verdier
mc_values = MC(y)
atc_values = ATC(y)
mc2_values = MC2(y)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(y, mc_values, label='Grensekostnad (GK)', color='blue')
plt.plot(y, mc2_values, label='Grensekostnad2 (GK)', color='blue')
plt.plot(y, atc_values, label='Gjennomsnittlig total kostnad (ATC)', color='green')

# Identifisere og highlight tilbudskurven (delen av MC over AVC)
supply_curve_y_before = y[mc_values > atc_values]
supply_curve_MC_before = mc_values[mc_values > atc_values]
supply_curve_y_after = y[mc2_values > atc_values]
supply_curve_MC_after = mc2_values[mc2_values > atc_values]

plt.plot(supply_curve_y_before, supply_curve_MC_before, label='Tilbudskurve - før lønnsøkning',  color='red')
plt.plot(supply_curve_y_after, supply_curve_MC_after, label='Tilbudskurve - etter lønnsøkning', color='orange')



# Sett aksene
plt.xlabel('Kvantum (y)')
plt.ylabel('Pris / Kostnad')
plt.title('Kostnadskurver (GK, AVC, ATC)')
plt.legend()
plt.grid(True)
plt.ylim(0, 100)  # Begrens y-aksen for klarhet
plt.xlim(0, 1000)  # Begrens x-aksen for klarhet
plt.show()

# %% [markdown]
# . Intuisjonen bak endringen
#
# - **Økte kostnader**: En lønnsøkning på 5% øker de variable kostnadene til bedriften fordi arbeidskraft blir dyrere.
# - **Marginalkostnadskurve**: I grafen skifter MC-kurven oppover og mot venstre fordi det koster mer å produsere hver ekstra enhet.
# - **Tilbudskurve**: Tilbudskurven, som er delen av MC-kurven over AVC, skifter også oppover. Dette betyr at for en gitt produksjonsmengde, vil bedriften kreve en høyere pris for å dekke de økte kostnadene.
# - **Markedseffekter**: På markedet kan dette føre til høyere priser og redusert tilbud.

# %% [markdown]
# # 4. Appendix

# %% [markdown]
# ## Kilder

# %% [markdown]
# Dereks github-repo og en del artikler Source 1-4

# %% [markdown]
# ## KI
#
# Jeg har brukt KI til å lage de fleste grafer, med noe justeringe fra min side.

# %% [markdown]
# ## Kode

# %% [markdown]
# ### Pakker

# %%
# Pakker
# !pip install pyjstat

import json
import pandas as pd
import requests
from pyjstat import pyjstat
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: pyjstat in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pyjstat) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pyjstat) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pyjstat) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pyjstat) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pyjstat) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pyjstat) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pyjstat) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pyjstat) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pyjstat) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pyjstat) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pyjstat) (1.16.0)

# %% [markdown]
# ### Oppgave 1

# %% [markdown]
# #### Dataframes

# %% [markdown]
# #### KPI

# %%
# KPI-df
# Koden er hentet fra kursrepoet til sok-1006

# Henter KPI-tabell med en JSON-spørring, dette er en tabell hvor 2015 = 100
# Gjør dette for å kunne konvertere omsetningen fra de andre tabellene til realpriser
# https://www.ssb.no/priser-og-prisindekser/nytt-referansear-2015-100-i-konsumprisindeksen-kpi

# Lim in PostUrl som spørringen skal postes mot
postUrl = "https://data.ssb.no/api/v0/no/table/03013/"

# spørring fra SSB
# I første instans laster jeg inn all dataen, selv om jeg bare opererer med tall fra 2000 og ut

apiQuery = {
  "query": [
    {
      "code": "Konsumgrp",
      "selection": {
        "filter": "vs:CoiCop2016niva1",
        "values": []
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": [
          "KpiIndMnd"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}


# Funksjon for å konvertere uttrekket til 2 dataframes, tar 2 paramtre (SSB)

def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds = pyjstat.Dataset.read(res.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df = ds.write('dataframe')
    # deretter dataframe med koder
    df_id = ds.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df, df_id, ds


df, df_id, ds = apiToDataframe(postUrl, apiQuery)


# gir kolonnen for KPI navnet KPI for å gjøre det lettere å holde oversikt

df.rename(columns={'value': 'KPI(2015=100)'}, inplace=True)

#Omformer månedlig til årlig KPI for å enklere matche andre datasettene jeg har

# Henter ut årsverdien
df['år'] = df['måned'].str[:4]

# Her lager jeg en enkel funksjon for å finne gjennomsnittsverdien for hvert år
aggregation_functions = {
    'KPI(2015=100)': 'mean'
}

# For å gjøre det enklere å bruke den flere ganger og holde orden i df'ene gir jeg den nytt navn
kpi_df = df

# Group by ´år´og bruker funksjonen
kpi_df = df.groupby('år').agg(aggregation_functions).reset_index()

# %% [markdown]
# #### ii) Omsetning hele næringen

# %%
# Omsetning i varhandel på 2-siffer nivå
# Bruker samme type API-spørring fra samme repo hver gang

# Lim in PostUrl som spørringen skal postes mot
postUrl = "https://data.ssb.no/api/v0/no/table/07312/"

# spørring fra SSB

apiQuery = {
  "query": [
    {
      "code": "NACE2007",
      "selection": {
        "filter": "vs:NACE2007vroms2",
        "values": [
          "47"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}


# Funksjon for å konvertere uttrekket til 2 dataframes, tar 2 paramtre (SSB)

def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds = pyjstat.Dataset.read(res.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df = ds.write('dataframe')
    # deretter dataframe med koder
    df_id = ds.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df, df_id, ds


df, df_id, ds = apiToDataframe(postUrl, apiQuery)

# gir kolonnen for Omsetning et bedre navn for å gjøre det lettere å holde oversikt

df.rename(columns={'value': 'Omsetning (mill.kr)'}, inplace=True)

# Henter ut årsverdien
df['år'] = df['termin'].str[:4]

# Her lager jeg en enkel funksjon for å finne den aggregerte omsetningen for hvert år
aggregation_functions = {
    'Omsetning (mill.kr)': 'sum'
}

# For å gjøre det enklere å bruke den flere ganger og holde orden i df'ene gir jeg den nytt navn
omsetning_47_df = df

# Group by ´år´og bruker funksjonen
omsetning_47_df = df.groupby('år').agg(aggregation_functions).reset_index()

#merger inn kpi_df for å kunne lage en kolonne med realverdier
omsetning_47_df = omsetning_47_df.merge(kpi_df, left_on='år', right_on='år', how='left')

# Lager en ny kolonne med realomsetning
omsetning_47_df['Realomsetning (mill.kr)(2015=100)'] = omsetning_47_df['Omsetning (mill.kr)'] * (100 /omsetning_47_df['KPI(2015=100)'])

omsetning_47_df['Realomsetning (mill.kr)(2015=100)'] = omsetning_47_df['Realomsetning (mill.kr)(2015=100)'].astype(int) # sikre hele tall

# %% [markdown]
# #### ii) Sysselsatte i detaljnæringen

# %%
# Omsetning i varhandel på 2-siffer nivå

# Lim in PostUrl som spørringen skal postes mot
postUrl = "https://data.ssb.no/api/v0/no/table/12910/"

# spørring fra SSB

apiQuery = {
  "query": [
    {
      "code": "NACE2007",
      "selection": {
        "filter": "vs:NACE2007StrNaring",
        "values": [
          "47"
        ]
      }
    },
    {
      "code": "Enhet",
      "selection": {
        "filter": "item",
        "values": [
          "31"
        ]
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": [
          "Enheter",
          "Sysselsatte",
          "Arsverk",
          "Oms"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}


# Funksjon for å konvertere uttrekket til 2 dataframes, tar 2 paramtre (SSB)

def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds = pyjstat.Dataset.read(res.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df = ds.write('dataframe')
    # deretter dataframe med koder
    df_id = ds.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df, df_id, ds


df, df_id, ds = apiToDataframe(postUrl, apiQuery)
df_12910 = df

df_12910 = pd.pivot_table(df_12910, values="value", index=["år"], columns=["statistikkvariabel"])

#merger inn kpi_df for å kunne lage en kolonne med realverdier
df_12910 = df_12910.merge(kpi_df, left_on='år', right_on='år', how='left')

# Lager en ny kolonne med realomsetning
df_12910['Realomsetning (mill.kr)(2015=100)'] = df_12910['Omsetning (mill. kr)'] * (100 /df_12910['KPI(2015=100)'])

df_12910['Realomsetning (mill.kr)(2015=100)'] = df_12910['Realomsetning (mill.kr)(2015=100)'].astype(int) # sikre hele tall

df_12910
# Out:
#      år  Antall enheter  Omsetning (mill. kr)  Sysselsatte   Årsverk  \
# 0  2017         36431.0              489421.7     232270.0  131610.0
# 1  2018         36421.0              500778.9     232297.0  129741.0
# 2  2019         35933.0              509067.0     228723.0  131342.0
# 3  2020         35655.0              561746.5     212240.0  131652.0
# 4  2021         36497.0              591848.6     214678.0  134872.0
# 5  2022         37196.0              611221.3     218741.0  134028.0
#
#    KPI(2015=100)  Realomsetning (mill.kr)(2015=100)
# 0     105.491667                             463943
# 1     108.408333                             461937
# 2     110.758333                             459619
# 3     112.183333                             500739
# 4     116.091667                             509811
# 5     122.783333                             497804

# %% [markdown]
# #### ii) Sysselsatte hele norge

# %%
# Omsetning i varhandel på 2-siffer nivå

# Lim in PostUrl som spørringen skal postes mot
postUrl = "https://data.ssb.no/api/v0/no/table/12910/"

# spørring fra SSB

apiQuery = {
  "query": [
    {
      "code": "NACE2007",
      "selection": {
        "filter": "vs:NACE2007StrAggr",
        "values": [
          "B-J+L-N+S"
        ]
      }
    },
    {
      "code": "Enhet",
      "selection": {
        "filter": "item",
        "values": [
          "31"
        ]
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": [
          "Sysselsatte"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}


# Funksjon for å konvertere uttrekket til 2 dataframes, tar 2 paramtre (SSB)

def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds = pyjstat.Dataset.read(res.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df = ds.write('dataframe')
    # deretter dataframe med koder
    df_id = ds.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df, df_id, ds


df, df_id, ds = apiToDataframe(postUrl, apiQuery)
df_12910_hele = df

# %% [markdown]
# #### iiiA) Detaljhandelen, spesifikke næringer

# %%
# Omsetning i varhandel på 4-siffer nivå

# Lim in PostUrl som spørringen skal postes mot
postUrl = "https://data.ssb.no/api/v0/no/table/07313/"

# spørring fra SSB

apiQuery = {
  "query": [
    {
      "code": "NACE2007",
      "selection": {
        "filter": "vs:NACE2007vroms4",
        "values": [
          "47.29",
          "47.65",
          "47.71",
          "47.75",
          "47.79"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}


# Funksjon for å konvertere uttrekket til 2 dataframes, tar 2 paramtre (SSB)

def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds = pyjstat.Dataset.read(res.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df = ds.write('dataframe')
    # deretter dataframe med koder
    df_id = ds.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df, df_id, ds


df, df_id, ds = apiToDataframe(postUrl, apiQuery)
Omsetning_07313 = df

Omsetning_07313.rename(columns={'value': 'Omsetning (mill.kr)'}, inplace=True)

#merger inn kpi_df for å kunne lage en kolonne med realverdier
Omsetning_07313 = Omsetning_07313.merge(kpi_df, left_on='år', right_on='år', how='left')

# Lager en ny kolonne med realomsetning
Omsetning_07313['Realomsetning (mill.kr)(2015=100)'] = Omsetning_07313['Omsetning (mill.kr)'] * (100 /Omsetning_07313['KPI(2015=100)'])

Omsetning_07313['Realomsetning (mill.kr)(2015=100)'] = Omsetning_07313['Realomsetning (mill.kr)(2015=100)'].astype(int) # sikre hele tall

Omsetning_07313
# Out:
#                                       næring (SN2007) statistikkvariabel  \
# 0   Butikkhandel med nærings- og nytelsesmidler el...          Omsetning
# 1   Butikkhandel med nærings- og nytelsesmidler el...          Omsetning
# 2   Butikkhandel med nærings- og nytelsesmidler el...          Omsetning
# 3   Butikkhandel med nærings- og nytelsesmidler el...          Omsetning
# 4   Butikkhandel med nærings- og nytelsesmidler el...          Omsetning
# ..                                                ...                ...
# 75                      Butikkhandel med brukte varer          Omsetning
# 76                      Butikkhandel med brukte varer          Omsetning
# 77                      Butikkhandel med brukte varer          Omsetning
# 78                      Butikkhandel med brukte varer          Omsetning
# 79                      Butikkhandel med brukte varer          Omsetning
#
#       år  Omsetning (mill.kr)  KPI(2015=100)  \
# 0   2008                 1723      87.983333
# 1   2009                 1754      89.916667
# 2   2010                 1751      92.091667
# 3   2011                 1813      93.275000
# 4   2012                 1884      93.925000
# ..   ...                  ...            ...
# 75  2019                  564     110.758333
# 76  2020                  650     112.183333
# 77  2021                  615     116.091667
# 78  2022                  778     122.783333
# 79  2023                 1031     129.558333
#
#     Realomsetning (mill.kr)(2015=100)
# 0                                1958
# 1                                1950
# 2                                1901
# 3                                1943
# 4                                2005
# ..                                ...
# 75                                509
# 76                                579
# 77                                529
# 78                                633
# 79                                795
#
# [80 rows x 6 columns]

# %% [markdown]
# #### iiiB) Detaljhandelen, fokus på netthandel

# %%
# Omsetning i varhandel på 2-siffer nivå

# Lim in PostUrl som spørringen skal postes mot
postUrl = "https://data.ssb.no/api/v0/no/table/07313/"

# spørring fra SSB

apiQuery = {
  "query": [
    {
      "code": "NACE2007",
      "selection": {
        "filter": "vs:NACE2007vroms4",
        "values": [
          "47.91"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}


# Funksjon for å konvertere uttrekket til 2 dataframes, tar 2 paramtre (SSB)

def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds = pyjstat.Dataset.read(res.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df = ds.write('dataframe')
    # deretter dataframe med koder
    df_id = ds.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df, df_id, ds


df, df_id, ds = apiToDataframe(postUrl, apiQuery)
Omsetning_07313_nett = df

Omsetning_07313_nett.rename(columns={'value': 'Omsetning (mill.kr)'}, inplace=True)

#merger inn kpi_df for å kunne lage en kolonne med realverdier
Omsetning_07313_nett = Omsetning_07313_nett.merge(kpi_df, left_on='år', right_on='år', how='left')

# Lager en ny kolonne med realomsetning
Omsetning_07313_nett['Realomsetning (mill.kr)(2015=100)'] = Omsetning_07313_nett['Omsetning (mill.kr)'] * (100 /Omsetning_07313['KPI(2015=100)'])

Omsetning_07313_nett['Realomsetning (mill.kr)(2015=100)'] = Omsetning_07313_nett['Realomsetning (mill.kr)(2015=100)'].astype(int) # sikre hele tall

# %% [markdown]
# #### Grafer

# %% [markdown]
# #### ii) Realomsetning i mill.kr

# %%
def plot_series(series, series_name, series_index=0, title="", subtitle="", undertext=""):
    palette = list(sns.palettes.mpl_palette('Dark2'))
    xs = series['år']
    ys = series['Realomsetning (mill.kr)(2015=100)']

    fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
    ax.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

    sns.despine(fig=fig, ax=ax)
    ax.set_xlabel('År')
    ax.set_ylabel('Realomsetning (mill.kr)(2015=100)')

    # Add title, subtitle, and undertext
    if title:
        fig.suptitle(title, fontsize=16)
    if subtitle:
        plt.title(subtitle, fontsize=12)
    if undertext:
        plt.figtext(0.1, -0.1, undertext, wrap=True, horizontalalignment='center', fontsize=10)

    plt.show()

df_sorted = omsetning_47_df.sort_values('år', ascending=True)
plot_series(df_sorted, 'Omsetning i detaljhandelen i Norge 2008-2023',
            title="Fig.1: Omsetning i detaljhandelen i Norge 2008-2023",
            subtitle="Realomsetning (mill.kr)(2015=100)",
            undertext="Kilde: Statistisk sentralbyrå")

# %% [markdown]
# #### ii) Sysselsetting Detaljhandelen vs Resten

# %%
import pandas as pd
import plotly.express as px
import plotly.subplots as sp

def create_pie_charts(df_retail, df_norway, years):
    # Merge DataFrames on 'år'
    df_merged = pd.merge(df_retail, df_norway, on='år', suffixes=('_detalj', '_norge'))

    # Calculate the number of non-retail employees
    df_merged['non_retail'] = df_merged['value'] - df_merged['Sysselsatte']

    # Create subplots: 1 row, len(years) columns with type 'domain' for pie charts
    fig = sp.make_subplots(
        rows=1, cols=len(years),
        subplot_titles=[f'{year}' for year in years],
        specs=[[{'type': 'domain'} for _ in years]]
    )

    # Define colors for the pie charts
    colors = ['#ff9999', '#66b3ff']

    # Add a pie chart for each selected year
    for i, year in enumerate(years):
        data = df_merged[df_merged['år'] == year]
        labels = ['Detaljhandel', 'Andre Næringer']
        values = [data['Sysselsatte'].values[0], data['non_retail'].values[0]]

        pie_fig = px.pie(
            values=values,
            names=labels,
            hole=0
        )

        pie_fig.update_traces(
            hoverinfo="percent+value",
            textinfo="percent",
            marker=dict(colors=colors)
        )

        # Add the pie chart to the subplot
        fig.add_trace(pie_fig.data[0], row=1, col=i+1)

    # Update layout
    fig.update_layout(
        title_text="Fig.2 Ansatte i Detaljnæringen mot resten av Norge 2017 og 2022",
        showlegend=True,
        legend=dict(
            x=0.5,
            y=-0.1,
            xanchor='center',
            orientation='h'
        )
    )

    fig.show()

# Example usage
df_retail = pd.DataFrame(df_12910)
df_norway = pd.DataFrame(df_12910_hele)

# Define the years for which you want to create pie charts
selected_years = [df_retail['år'].min(), df_retail['år'].max()]

create_pie_charts(df_retail, df_norway, selected_years)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0286ffd9-6e4c-4464-acfb-2e7b489df403" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0286ffd9-6e4c-4464-acfb-2e7b489df403")) {                    Plotly.newPlot(                        "0286ffd9-6e4c-4464-acfb-2e7b489df403",                        [{"domain":{"x":[0.0,0.45],"y":[0.0,1.0]},"hole":0,"hoverinfo":"percent+value","hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Detaljhandel","Andre N\u00e6ringer"],"legendgroup":"","marker":{"colors":["#ff9999","#66b3ff"]},"name":"","showlegend":true,"textinfo":"percent","values":[232270.0,1376045.0],"type":"pie"},{"domain":{"x":[0.55,1.0],"y":[0.0,1.0]},"hole":0,"hoverinfo":"percent+value","hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Detaljhandel","Andre N\u00e6ringer"],"legendgroup":"","marker":{"colors":["#ff9999","#66b3ff"]},"name":"","showlegend":true,"textinfo":"percent","values":[218741.0,1688682.0],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0," ...

# %%
import pandas as pd
import plotly.express as px

# Create DataFrames
df_retail = pd.DataFrame(df_12910)
df_norway = pd.DataFrame(df_12910_hele)

# Merge DataFrames on 'år'
df_merged = pd.merge(df_retail, df_norway, on='år', suffixes=('_detalj', '_norge'))

# Calculate the number of non-retail employees
df_merged['non_retail'] = df_merged['value'] - df_merged['Sysselsatte']

# Create an interactive pie chart for each year
for year in df_merged['år']:
    data = df_merged[df_merged['år'] == year]
    labels = ['Detaljhandel', 'Andre Næringer']
    values = [data['Sysselsatte'].values[0], data['non_retail'].values[0]]

    fig = px.pie(
        values=values,
        names=labels,
        title=f'Ansatte i Detaljnæringen i {year}',
        hole=0.3
    )

    fig.update_traces(
        hoverinfo="percent+value",
        textinfo="percent",
        marker=dict(colors=['#ff9999','#66b3ff'])
    )

    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="07969e70-64e8-4837-b21e-63845ea2141c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07969e70-64e8-4837-b21e-63845ea2141c")) {                    Plotly.newPlot(                        "07969e70-64e8-4837-b21e-63845ea2141c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Detaljhandel","Andre N\u00e6ringer"],"legendgroup":"","name":"","showlegend":true,"values":[232270.0,1376045.0],"type":"pie","marker":{"colors":["#ff9999","#66b3ff"]},"hoverinfo":"percent+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="72156ffd-dcd0-498f-9060-314e614aea5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72156ffd-dcd0-498f-9060-314e614aea5e")) {                    Plotly.newPlot(                        "72156ffd-dcd0-498f-9060-314e614aea5e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Detaljhandel","Andre N\u00e6ringer"],"legendgroup":"","name":"","showlegend":true,"values":[232297.0,1408800.0],"type":"pie","marker":{"colors":["#ff9999","#66b3ff"]},"hoverinfo":"percent+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b5b44561-8336-4a5b-962f-148ad3265908" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5b44561-8336-4a5b-962f-148ad3265908")) {                    Plotly.newPlot(                        "b5b44561-8336-4a5b-962f-148ad3265908",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Detaljhandel","Andre N\u00e6ringer"],"legendgroup":"","name":"","showlegend":true,"values":[228723.0,1438636.0],"type":"pie","marker":{"colors":["#ff9999","#66b3ff"]},"hoverinfo":"percent+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="76b6facc-cf71-4870-a164-5c3b2c4b16b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76b6facc-cf71-4870-a164-5c3b2c4b16b8")) {                    Plotly.newPlot(                        "76b6facc-cf71-4870-a164-5c3b2c4b16b8",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Detaljhandel","Andre N\u00e6ringer"],"legendgroup":"","name":"","showlegend":true,"values":[212240.0,1365939.0],"type":"pie","marker":{"colors":["#ff9999","#66b3ff"]},"hoverinfo":"percent+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ac57e1e2-39bd-407b-ad96-12a7ddc239ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac57e1e2-39bd-407b-ad96-12a7ddc239ad")) {                    Plotly.newPlot(                        "ac57e1e2-39bd-407b-ad96-12a7ddc239ad",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Detaljhandel","Andre N\u00e6ringer"],"legendgroup":"","name":"","showlegend":true,"values":[214678.0,1599805.0],"type":"pie","marker":{"colors":["#ff9999","#66b3ff"]},"hoverinfo":"percent+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d9fceea4-2bc6-43f4-a78f-0482626e566f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9fceea4-2bc6-43f4-a78f-0482626e566f")) {                    Plotly.newPlot(                        "d9fceea4-2bc6-43f4-a78f-0482626e566f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Detaljhandel","Andre N\u00e6ringer"],"legendgroup":"","name":"","showlegend":true,"values":[218741.0,1688682.0],"type":"pie","marker":{"colors":["#ff9999","#66b3ff"]},"hoverinfo":"percent+value","textinfo":"percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# #### iiiA) Detaljnæringen utvalgte markeder

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Split the data for the two industries
spill = Omsetning_07313[Omsetning_07313["næring (SN2007)"] == "Butikkhandel med spill og leker"]
klar = Omsetning_07313[Omsetning_07313["næring (SN2007)"] == "Butikkhandel med klær"]
kosm = Omsetning_07313[Omsetning_07313["næring (SN2007)"] == "Butikkhandel med kosmetikk og toalettartikler"]
brukt = Omsetning_07313[Omsetning_07313["næring (SN2007)"] == "Butikkhandel med brukte varer"]

# Plotting
plt.figure(figsize=(12, 8))
plt.plot(spill["år"], spill["Realomsetning (mill.kr)(2015=100)"], marker='o', label='Butikkhandel med spill og leker')
plt.plot(klar["år"], klar["Realomsetning (mill.kr)(2015=100)"], marker='o', label='Butikkhandel med klær')
plt.plot(kosm["år"], kosm["Realomsetning (mill.kr)(2015=100)"], marker='o', label='Butikkhandel med kosmetikk og toalettartikler')
plt.plot(brukt["år"], brukt["Realomsetning (mill.kr)(2015=100)"], marker='o', label='Butikkhandel med brukte varer')

# Set labels and title
plt.xlabel('År')
plt.ylabel('Realomsetning (mill. kr) (2015=100)')
plt.title('Realomsetning for Butikkhandel med klær og skotøy og lærvarer (2008-2023)')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### iiiB) Detaljnæringen netthandel

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['år']
  ys = series['Realomsetning (mill.kr)(2015=100)']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = Omsetning_07313_nett.sort_values('år', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('år')
_ = plt.ylabel('Realomsetning (mill.kr)(2015=100)')

# %%
# Andel av omsetningen i hele detaljnæringen som er netthandel

# %% [markdown]
# ### Oppgave 2

# %% [markdown]
# #### Dataframes

# %%
# last inn pakker

import json
import pandas as pd
import requests
from pyjstat import pyjstat

# Lim in PostUrl som spørringen skal postes mot
postUrl = "https://data.ssb.no/api/v0/no/table/12910/"

# spørring fra SSB

apiQuery = {
  "query": [
    {
      "code": "NACE2007",
      "selection": {
        "filter": "vs:NACE2007StrNaringUndGr",
        "values": [
          "47.111",
          "47.112",
          "47.190",
          "47.210",
          "47.220",
          "47.230",
          "47.241",
          "47.242",
          "47.251",
          "47.259",
          "47.260",
          "47.291",
          "47.292",
          "47.299",
          "47.300",
          "47.410",
          "47.420",
          "47.430",
          "47.510",
          "47.521",
          "47.522",
          "47.523",
          "47.524",
          "47.529",
          "47.531",
          "47.532",
          "47.533",
          "47.540",
          "47.591",
          "47.592",
          "47.593",
          "47.594",
          "47.599",
          "47.610",
          "47.620",
          "47.630",
          "47.641",
          "47.642",
          "47.650",
          "47.710",
          "47.721",
          "47.722",
          "47.730",
          "47.740",
          "47.750",
          "47.761",
          "47.762",
          "47.771",
          "47.772",
          "47.781",
          "47.782",
          "47.789",
          "47.791",
          "47.792",
          "47.799",
          "47.810",
          "47.820",
          "47.890",
          "47.911",
          "47.912",
          "47.913",
          "47.914",
          "47.915",
          "47.916",
          "47.917",
          "47.919",
          "47.990"
        ]
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": [
          "Produksjonsverdi",
          "Lonnskost",
          "BruttoInvesteringer"
        ]
      }
    },
    {
      "code": "Tid",
      "selection": {
        "filter": "item",
        "values": [
          "2022"
        ]
      }
    }
  ],
  "response": {
    "format": "json-stat2"
  }
}


# Funksjon for å konvertere uttrekket til 2 dataframes, tar 2 paramtre (SSB)

def apiToDataframe(postUrl, query):

    # postUrl som spørringen skal postes mot
    # Spørringen og endepunktet til API-et kan hentes fra Statistikkbanken.

    res = requests.post(postUrl, json=query)
    # legger resultat i ds. DS har i tillegg en del metadata
    ds = pyjstat.Dataset.read(res.text)
    # skriver resultatet til to dataframes
    # først dataframe med tekst
    df = ds.write('dataframe')
    # deretter dataframe med koder
    df_id = ds.write('dataframe', naming='id')
    # returnerer også ds i tilfelle en trenger metadata
    return df, df_id, ds


df, df_id, ds = apiToDataframe(postUrl, apiQuery)

# slå sammen verdier for foretak og bedrift

df_sum = df.groupby(['næring (SN2007)', 'statistikkvariabel']).sum().reset_index()

# dropp kolonner

df_sum = df_sum.drop(columns=['foretak/bedrift', 'år'])

# pivot

df_pivot = df_sum.pivot_table(index='næring (SN2007)', columns='statistikkvariabel', values='value')

# lag en kopi av datasettet

data = df_pivot.copy()

# fjern rader med verdier lik 0

data = data.drop(data[data.eq(0).any(axis=1)].index)

#vis datasettet

oppg_2_df = data

oppg_2_df
# Out:
# statistikkvariabel                                  Bruttoinvesteringer (mill. kr)  \
# næring (SN2007)
# Butikkhandel ikke nevnt annet sted                                           189.3
# Butikkhandel med antikviteter                                                  0.1
# Butikkhandel med apotekvarer                                                 311.9
# Butikkhandel med audio- og videoutstyr                                        31.6
# Butikkhandel med bakervarer og konditorvarer                                  62.2
# ...                                                                            ...
# Postordre-/Internetthandel med helsekost                                      12.2
# Postordre-/Internetthandel med tekstiler, utsty...                           109.4
# Postordre-/internetthandel med bøker, papir, av...                             6.1
# Torghandel med andre varer                                                     2.8
# Torghandel med næringsmidler, drikkevarer og to...                            17.0
#
# statistikkvariabel                                  Lønnskostnader (mill. kr)  \
# næring (SN2007)
# Butikkhandel ikke nevnt annet sted                                     2331.1
# Butikkhandel med antikviteter                                            30.4
# Butikkhandel med apotekvarer                                          10713.4
# Butikkhandel med audio- og videoutstyr                                  398.8
# Butikkhandel med bakervarer og konditorvarer                           1282.5
# ...                                                                       ...
# Postordre-/Internetthandel med helsekost                                248.1
# Postordre-/Internetthandel med tekstiler, utsty...                     1137.9
# Postordre-/internetthandel med bøker, papir, av...                      114.6
# Torghandel med andre varer                                               19.8
# Torghandel med næringsmidler, drikkevarer og to...                      107.9
#
# statistikkvariabel                                  Produksjonsverdi (mill. kr)
# næring (SN2007)
# Butikkhandel ikke nevnt annet sted                                       5892.0
# Butikkhandel med antikviteter                                             110.1
# Butikkhandel med apotekvarer                                            18990.5
# Butikkhandel med audio- og videoutstyr                                    848.6
# Butikkhandel med bakervarer og konditorvarer                             2792.3
# ...                                                                         ...
# Postordre-/Internetthandel med helsekost                                 2111.4
# Postordre-/Internetthandel med tekstiler, utsty...                       6152.3
# Postordre-/internetthandel med bøker, papir, av...                        483.2
# Torghandel med andre varer                                                 48.8
# Torghandel med næringsmidler, drikkevarer og to...                        253.1
#
# [61 rows x 3 columns]

# %% [markdown]
# #### Funksjoner og utregninger

# %%
# importer pakkene som vi trenger
import numpy as np
from matplotlib import pyplot as plt
import sympy as sp

#1)
# definer nye symboler
N, Z, K, a, b = sp.symbols('N Z K a b', positive=True, real=True)

# definer produktfn
def prod_cd(Z, N,K,a,b):
    return Z*(N**a)*(K**b)



# finn "overskudd" fra en fordobling av innsats i forhold til dobbel så mye produksjon
# NB begge innsatsfaktorene fordobles

overskudd_cd=prod_cd(Z,2*N,2*K,a,b)-2*prod_cd(Z, N,K,a,b)
sp.simplify(overskudd_cd)

def prod_4(N,K,a,b,Z):
    return Z*N**a*K**b

# ta log av produktfunksjonen log(x)=....
prod_log=sp.log(prod_4(N,K,a,b,Z))
prod_log

# som ikke er på ønsket form. La oss utvide uttrykket vha sp.expand()
sp.expand(prod_log)
# Out:
# a*log(N) + b*log(K) + log(Z)

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

oppg_2_df['log_K'] = np.log(oppg_2_df['Bruttoinvesteringer (mill. kr)'])
oppg_2_df['log_N'] = np.log(oppg_2_df['Lønnskostnader (mill. kr)'])
oppg_2_df['log_x'] = np.log(oppg_2_df['Produksjonsverdi (mill. kr)'])

X = oppg_2_df[['log_K', 'log_N']]
X = sm.add_constant(X)  # Legg til konstant
y = oppg_2_df['log_x']

model = sm.OLS(y, X).fit()
model_summary = model.summary()
print(model_summary)

log_Z = 1.5837
Z = np.exp(log_Z)
a = 0.8088
b = 0.1513
print(model_summary)
print(f"Z: {Z}")
print(f"a: {a}")
print(f"b: {b}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  log_x   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     522.2
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):           8.16e-38
# Time:                        16:14:38   Log-Likelihood:                -27.062
# No. Observations:                  61   AIC:                             60.12
# Df Residuals:                      58   BIC:                             66.46
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5837      0.290      5.465      0.000       1.004       2.164
# log_K          0.1513      0.060      2.536      0.014       0.032       0.271
# log_N          0.8088      0.073     11.109      0.000       0.663       0.954
# ==============================================================================
# Omnibus:                       11.272   Durbin-Watson:                   1.439
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               18.845
# Skew:                           0.561   Prob(JB):                     8.09e-05
# Kurtosis:                       5.481   Cond. No.                         48.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  log_x   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     522.2
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):           8.16e-38
# Time:                        16:14:38   Log-Likelihood:                -27.062
# No. Observations:                  61   AIC:                             60.12
# Df Residuals:                      58   BIC:                             66.46
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5837      0.290      5.465      0.000       1.004       2.164
# log_K          0.1513      0.060      2.536      0.014       0.032       0.271
# log_N          0.8088      0.073     11.109      0.000       0.663       0.954
# ==============================================================================
# Omnibus:                       11.272   Durbin-Watson:                   1.439
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               18.845
# Skew:                           0.561   Prob(JB):                     8.09e-05
# Kurtosis:                       5.481   Cond. No.                         48.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Z: 4.872952420935827
# a: 0.8088
# b: 0.1513

# %% [markdown]
# ### Oppgave 3

# %% [markdown]
# #### Finne K_0

# %%
# Finner gjennomsnittelig ved å ta gjennomsnittet av 'Bruttoinvesteringer (mill. kr)'
print(oppg_2_df['Bruttoinvesteringer (mill. kr)'].mean())
# Out:
# 271.2737704918033

# %% [markdown]
# #### Funksjonsuttrykk

# %% [markdown]
# ##### i) Skriv et uttrykk for bedriftens variable kostnader og totale kostnader på kort sikt som en funksjon av mengde produsert ($y$).

# %% [markdown]
# ##### ii) Finn uttrykk for bedriftens grensekostnad og gjennomsnittskostnad (total og variabel)

# %%
# Grensekostnad: AVC = VC/y
AVC = lambda y: VC(y) / y
AVC_new = lambda y: VC_new(y) / y

# Gjennomsnittskostnad: ATC = TC/y
ATC = lambda y: TC(y) / y
ATC_new = lambda y: TC_new(y) / y

# %% [markdown]
# #### Graf

# %% [markdown]
# ##### iii) Bruk ditt svar til ii) for å tegne bedriftens tilbudskurve i en figur. Forklar figuren nøye.

# %%
# Graf for oppgave 3
import numpy as np
import matplotlib.pyplot as plt

# Definer konstanter med de gitte verdiene
a = 0.81
Z = 4.75
K0 = 271
w = 287
b = 0.15
k = w * (1 / (Z * K0**b))**(1/a)

# Definer grensekostnadsfunksjonen
def MC(y):
    return (k / a) * y**(1/a - 1)

# Definer gjennomsnittlig variabel kostnadsfunksjon (AVC) og gjennomsnittlig total kostnadsfunksjon (ATC)
def AVC(y):
    return k * y**(1/a - 1)

def ATC(y):
    return AVC(y) + K0 / y  # cK0 is a placeholder for fixed cost per unit, assume c = 1 for simplification

# Lag en rekke med produksjonsnivåer
y = np.linspace(0.1, 1000, 1000)  # unngå y=0 for å unngå deling på null

# Beregn MC, AVC og ATC verdier
mc_values = MC(y)
avc_values = AVC(y)
atc_values = ATC(y)

# Identifisere og highlight tilbudskurven (delen av MC over AVC)
supply_curve_y_before = y[mc_values > atc_values]
supply_curve_MC_before = mc_values[mc_values > atc_values]


# Plotting
plt.figure(figsize=(10, 6))
plt.plot(y, mc_values, label='Grensekostnad (GK)', color='blue')
plt.plot(y, atc_values, label='Gjennomsnittlig total kostnad (ATC)', color='green')
plt.plot(supply_curve_y_before, supply_curve_MC_before, label='Tilbudskurve',  color='red')

# Sett aksene
plt.xlabel('Kvantum (y)')
plt.ylabel('Pris / Kostnad')
plt.title('Kostnadskurver (GK, AVC, ATC)')
plt.legend()
plt.grid(True)
plt.ylim(0, 100)  # Begrens y-aksen for klarhet
plt.xlim(0, 1000)  # Begrens x-aksen for klarhet
plt.show()

# %% [markdown]
# ##### iv) Anta at lønnsoppgjøret gir arbeidere i "Helt midt på treet" en lønnsøkning på 5%.

# %%
# Graf for oppgave 3.2
import numpy as np
import matplotlib.pyplot as plt

# Definer konstanter med de gitte verdiene
a = 0.81
Z = 4.75
K0 = 271
w = 287
w2 = w * 1.05
b = 0.15
k = w * (1 / (Z * K0**b))**(1/a)
k2 = w2 * (1 / (Z * K0**b))**(1/a)

# Definer grensekostnadsfunksjonen
def MC(y):
    return (k / a) * y**(1/a - 1)

# Definer gjennomsnittlig variabel kostnadsfunksjon (AVC) og gjennomsnittlig total kostnadsfunksjon (ATC)
def AVC(y):
    return k * y**(1/a - 1)

def ATC(y):
    return AVC(y) + K0 / y  # cK0 is a placeholder for fixed cost per unit, assume c = 1 for simplification

# Definer grensekostnadsfunksjonen
def MC2(y):
    return (k2 / a) * y**(1/a - 1)

# Lag en rekke med produksjonsnivåer
y = np.linspace(0.1, 1000, 1000)  # unngå y=0 for å unngå deling på null

# Beregn MC, AVC og ATC verdier
mc_values = MC(y)
atc_values = ATC(y)
mc2_values = MC2(y)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(y, mc_values, label='Grensekostnad (GK)', color='blue')
plt.plot(y, mc2_values, label='Grensekostnad2 (GK)', color='blue')
plt.plot(y, atc_values, label='Gjennomsnittlig total kostnad (ATC)', color='green')

# Identifisere og highlight tilbudskurven (delen av MC over AVC)
supply_curve_y_before = y[mc_values > atc_values]
supply_curve_MC_before = mc_values[mc_values > atc_values]
supply_curve_y_after = y[mc2_values > atc_values]
supply_curve_MC_after = mc2_values[mc2_values > atc_values]

plt.plot(supply_curve_y_before, supply_curve_MC_before, label='Tilbudskurve - før lønnsøkning', linestyle=':', color='red')
plt.plot(supply_curve_y_after, supply_curve_MC_after, label='Tilbudskurve - etter lønnsøkning', linestyle='-.', color='red')



# Sett aksene
plt.xlabel('Kvantum (y)')
plt.ylabel('Pris / Kostnad')
plt.title('Kostnadskurver (GK, AVC, ATC)')
plt.legend()
plt.grid(True)
plt.ylim(0, 100)  # Begrens y-aksen for klarhet
plt.xlim(0, 1000)  # Begrens x-aksen for klarhet
plt.show()
